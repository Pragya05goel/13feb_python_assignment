# %% [markdown]
# ## ASSIGNMENT

# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# Since Exception class is a base class for all the exceptions therefore it is inherited by various user-defined classes to handle different types of python raise an exception with message.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect module
import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy 
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(Exception)
# Out:
# Hierarchy for Built-in exceptions is :
#  Exception
# --- TypeError
# ------ FloatOperation
# ------ MultipartConversionError
# --- StopAsyncIteration
# --- StopIteration
# --- ImportError
# ------ ModuleNotFoundError
# ------ ZipImportError
# --- OSError
# ------ ConnectionError
# --------- BrokenPipeError
# --------- ConnectionAbortedError
# --------- ConnectionRefusedError
# --------- ConnectionResetError
# ------------ RemoteDisconnected
# ------ BlockingIOError
# ------ ChildProcessError
# ------ FileExistsError
# ------ FileNotFoundError
# ------ IsADirectoryError
# ------ NotADirectoryError
# ------ InterruptedError
# --------- InterruptedSystemCall
# ------ PermissionError
# ------ ProcessLookupError
# ------ TimeoutError
# ------ UnsupportedOperation
# ------ itimer_error
# ------ herror
# ------ gaierror
# ------ SSLError
# --------- SSLCertVerificationError
# --------- SSLZeroReturnError
# --------- SSLWantWriteError
# --------- SSLWantReadError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# Various arithmetic errors such as :
#
# . OverflowError
#
# . ZeroDivisionError
#
# . FloatingPointError

# %%
## ZeroDivisionError

try:
    a=10
    10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
## OverflowError
import math
try:
    math.exp(4500)
except OverflowError as e:
    print(e)
# Out:
# math range error

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# Lookup Error acts as a base class for the exceptions that occur when a key or index used on a mapping or sequence of a list/dictionary is invalid or does not exists.
#
# The two types of exceptions raised are:
#
# IndexError
#
# KeyError

# %%
## KeyError
try:
    d={"name":"John","id":"@13"}
    d["phone_no"]
except KeyError as e:
    print(e)
# Out:
# 'phone_no'

# %%
## IndexError

try:
    l=[1,2,3,4]
    l[10]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# An ImportError is raised when the import statement is unable to load a module or when the “from list” in from … import has a name that cannot be found and  is usually displayed with the message that there is “No module named (…)” or “cannot import name (…)”.
#
#
# ModuleNotFoundError is the subclass of ImportError which is raised by import when a module could not be found. It is also raised when None is found in sys.modules.

# %%
try:
    import times
except ImportError as e:
    print(e)
# Out:
# No module named 'times'

# %%
try:
    import john
except ModuleNotFoundError as e:
    print(e)
# Out:
# No module named 'john'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1)Always use specific error exception rather than general one i.e. if you know what type of error is going to occur then use that specific error only as an exception don't go for "Exception class".
#
# 2)Always print a valid message while handling the errors.
#
# 3)Always log all your errors in a permanent file.
#
# 4)Don't use unnecessary multiple exceptions.
#
# 5)Try to keep proper Documentation
#
# 6)Clean-up all the resources.

# %% [markdown]
# ----
